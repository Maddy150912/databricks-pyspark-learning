# %% [markdown]
# ## Reading table

# %%
df = spark.read.table("samples.bakehouse.sales_franchises")

# %% [markdown]
# ## View the data using show() & display() method

# %%
df.show()

# %%
df.display()

# %% [markdown]
# ## Writing data

# %%
df.write.saveAsTable("test.test_schema.test_table")

# %% [markdown]
# ## Limit the number of records in DataFrame

# %%
df2 = df.limit(10)

# %%
df2.count()

# %% [markdown]
# ## Show the schema

# %%
df2.printSchema()
